# %% [markdown]
# <a href="https://colab.research.google.com/github/elanghairilanam/Portfolio-Data-Science/blob/main/Probability%20and%20Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import bernoulli

koin = bernoulli.rvs(size = 12 , p = 0.5)

sns.histplot(koin)
plt.show()

# %%
from scipy.stats import binom

koin = binom.rvs(size = 1000, n=10, p=0.5)

sns.histplot(koin)
plt.show()

# %%
from scipy.stats import poisson

cacat = poisson.rvs(size = 1000 , mu=2)

sns.histplot(cacat)
plt.show()

# %%
from scipy.stats import uniform

uniform_data = uniform.rvs(size = 1000, loc = 0, scale = 9)

sns.histplot(uniform_data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.stats import norm

data_nilai = norm.rvs(size = 1000, loc = 70, scale = 10)

sns.histplot(data_nilai)
plt.show()

# %%
from scipy.stats import expon

data_tunggu = expon.rvs(scale = 1, loc = 5, size = 1000)

sns.histplot(data_tunggu)
plt.show()
